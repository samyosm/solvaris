# %%
# !pip install matplotlib

# %%
import solvaris
import numpy as np
import matplotlib.pyplot as plt

# %%
a = 1
b = 0
c = -10

# %%
x = np.arange(-10, 10, 0.01)
y = a * x*x + b * x + c

# %%
x1, x2 = solvaris.quadratic(a,b,c)
x1, x2
# Out:
# (3.1622776985168457, -3.1622776985168457)

# %%
plt.plot(x,y)
plt.scatter(x1, 0)
plt.scatter(x2, 0)
